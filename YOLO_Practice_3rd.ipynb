# %%
# !pip install PyYAML

# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.7/645.7 kB 9.1 MB/s eta 0:00:00
# ...

# %%
data = {
    'train': '/content/drive/MyDrive/celebrity/Train/images',
    'val': '/content/drive/MyDrive/celebrity/Valid/images',
    'nc':20,
    'names': ['Daehyen','Hani','Heechul','Sinyae',
              'Jaeduck','Kulkeng','Jonghyen','Amber',
              'Jongseok','Nana','Dio','Kenyoung',
              'Junkkook','Yeyin','Dongjoon','Kayin',
              'GD','Mina','Umin','Sohee']
}

# %%
import yaml
with open('/content/drive/MyDrive/celebrity/celebrity.yaml','w') as f:
    yaml.dump(data, f)

# %%
with open('/content/drive/MyDrive/celebrity/celebrity.yaml','r') as f:
    celebrity_yaml = yaml.safe_load(f)
display(celebrity_yaml)
# Out:
# {'names': ['Daehyen',
#   'Hani',
#   'Heechul',
#   'Sinyae',
#   'Jaeduck',
#   'Kulkeng',
#   'Jonghyen',
#   'Amber',
#   'Jongseok',
#   'Nana',
#   'Dio',
#   'Kenyoung',
#   'Junkkook',
#   'Yeyin',
#   'Dongjoon',
#   'Kayin',
#   'GD',
#   'Mina',
#   'Umin',
#   'Sohee'],
#  'nc': 20,
#  'train': '/content/drive/MyDrive/celebrity/Train/images',
#  'val': '/content/drive/MyDrive/celebrity/Valid/images'}

# %%
import ultralytics
from ultralytics import YOLO

# %%
# 객체 감지 (yolov8l.pt, yolov8m.pt, yolov8n.pt, yolov8s.pt, yolov8x.pt, yolov8x6.pt)
# 분할 (yolov8l-seg.pt, yolov8m-seg.pt, yolov8n-seg.pt, yolov8s-seg.pt, yolov8x-seg.pt)
# 분류 (yolov8l-cls.pt, yolov8m-cls.pt, yolov8n-cls.pt, yolov8s-cls.pt, yolov8x-cls.pt)

# %%
# YOLO("사전학습된 모델명")
model = YOLO("yolov8n.pt")

# %%
model.names
# Out:
# {0: 'person',
#  1: 'bicycle',
#  2: 'car',
#  3: 'motorcycle',
#  4: 'airplane',
#  5: 'bus',
#  6: 'train',
#  7: 'truck',
#  8: 'boat',
#  9: 'traffic light',
#  10: 'fire hydrant',
#  11: 'stop sign',
#  12: 'parking meter',
#  13: 'bench',
#  14: 'bird',
#  15: 'cat',
#  16: 'dog',
#  17: 'horse',
#  18: 'sheep',
#  19: 'cow',
#  20: 'elephant',
#  21: 'bear',
#  22: 'zebra',
#  23: 'giraffe',
#  24: 'backpack',
#  25: 'umbrella',
#  26: 'handbag',
#  27: 'tie',
#  28: 'suitcase',
#  29: 'frisbee',
#  30: 'skis',
#  31: 'snowboard',
#  32: 'sports ball',
#  33: 'kite',
#  34: 'baseball bat',
#  35: 'baseball glove',
#  36: 'skateboard',
#  37: 'surfboard',
#  38: 'tennis racket',
#  39: 'bottle',
#  40: 'wine glass',
#  41: 'cup',
#  42: 'fork',
#  43: 'knife',
#  44: 'spoon',
#  45: 'bowl',
#  46: 'banana',
#  47: 'apple',
#  48: 'sandwich',
#  49: 'orange',
#  50: 'broccoli',
#  51: 'carrot',
#  52: 'hot dog',
#  53: 'pizza',
#  54: 'donut',
#  55: 'cake',
#  56: 'chair',
# ...

# %%
model.train(data='/content/drive/MyDrive/celebrity/celebrity.yaml', epochs = 100, patience =5, batch = 32, imgsz = 416)
# Out:
# Ultralytics YOLOv8.0.215 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model.names
# Out:
# {0: 'Daehyen',
#  1: 'Hani',
#  2: 'Heechul',
#  3: 'Sinyae',
#  4: 'Jaeduck',
#  5: 'Kulkeng',
#  6: 'Jonghyen',
#  7: 'Amber',
#  8: 'Jongseok',
#  9: 'Nana',
#  10: 'Dio',
#  11: 'Kenyoung',
#  12: 'Junkkook',
#  13: 'Yeyin',
#  14: 'Dongjoon',
#  15: 'Kayin',
#  16: 'GD',
#  17: 'Mina',
#  18: 'Umin',
#  19: 'Sohee'}

# %%
from glob import glob

# %%
test_img = glob('/content/drive/MyDrive/celebrity/Test/images/*')

# %%
len(test_img)
# Out:
# 83

# %%
test_img.sort()

# %%
results = model.predict(source = '/content/drive/MyDrive/celebrity/Train/images/', save = True)
# Out:
# image 1/188 /content/drive/MyDrive/celebrity/Train/images/Amber_001.jpg: 416x288 1 Jonghyen, 1 Amber, 12.1ms
# image 2/188 /content/drive/MyDrive/celebrity/Train/images/Amber_002.jpg: 416x288 1 Amber, 1 Kenyoung, 43.4ms
# image 3/188 /content/drive/MyDrive/celebrity/Train/images/Amber_003.jpg: 416x320 1 Amber, 1 Dio, 13.3ms
# image 4/188 /content/drive/MyDrive/celebrity/Train/images/Amber_004.jpg: 416x320 1 Amber, 1 Jongseok, 10.7ms
# image 5/188 /content/drive/MyDrive/celebrity/Train/images/Amber_005.jpg: 416x288 1 Amber, 11.0ms
# image 6/188 /content/drive/MyDrive/celebrity/Train/images/Dio_001.jpg: 416x384 1 Dio, 21.3ms
# image 7/188 /content/drive/MyDrive/celebrity/Train/images/Dio_002.jpg: 416x320 1 Jongseok, 1 Kenyoung, 10.6ms
# image 8/188 /content/drive/MyDrive/celebrity/Train/images/Dio_003.jpg: 416x288 1 Jongseok, 1 Dio, 10.9ms
# image 9/188 /content/drive/MyDrive/celebrity/Train/images/Dio_004.jpg: 288x416 1 Dio, 12.7ms
# ...

# %%
results
# Out:
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Daehyen', 1: 'Hani', 2: 'Heechul', 3: 'Sinyae', 4: 'Jaeduck', 5: 'Kulkeng', 6: 'Jonghyen', 7: 'Amber', 8: 'Jongseok', 9: 'Nana', 10: 'Dio', 11: 'Kenyoung', 12: 'Junkkook', 13: 'Yeyin', 14: 'Dongjoon', 15: 'Kayin', 16: 'GD', 17: 'Mina', 18: 'Umin', 19: 'Sohee'}
#  orig_img: array([[[186, 160, 130],
#          [188, 162, 132],
#          [190, 164, 134],
#          ...,
#          [193, 168, 142],
#          [185, 160, 134],
#          [185, 160, 134]],
#
#         [[187, 161, 131],
#          [188, 162, 132],
#          [190, 164, 134],
#          ...,
#          [191, 166, 140],
#          [189, 164, 138],
#          [189, 164, 138]],
#
#         [[188, 162, 132],
#          [189, 163, 133],
#          [191, 165, 135],
#          ...,
#          [190, 165, 139],
#          [193, 168, 142],
#          [193, 168, 142]],
#
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
